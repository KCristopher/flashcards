# %%
import pandas as pd
import random as r

# %%
df = pd.read_csv('french_words.csv')
df.head()
# Out:
#    Number French in English
# 0       1  comme         as
# 1       2     je          I
# 2       3    son        his
# 3       4    que       that
# 4       5     il         he

# %%
words_translations = [*zip(df['French'], df['in English'])]
words_translations
# Out:
# [('comme', 'as'),
#  ('je', 'I'),
#  ('son', 'his'),
#  ('que', 'that'),
#  ('il', 'he'),
#  ('était', 'was'),
#  ('pour', 'for'),
#  ('sur', 'on'),
#  ('sont', 'are'),
#  ('avec', 'with'),
#  ('ils', 'they'),
#  ('être', 'be'),
#  ('à', 'at'),
#  ('un', 'one'),
#  ('avoir', 'have'),
#  ('ce', 'this'),
#  ('à partir de', 'from'),
#  ('par', 'by'),
#  ('chaud', 'hot'),
#  ('mot', 'word'),
#  ('mais', 'but'),
#  ('que', 'what'),
#  ('certains', 'some'),
#  ('est', 'is'),
#  ('il', 'it'),
#  ('vous', 'you'),
#  ('ou', 'or'),
#  ('eu', 'had'),
#  ('la', 'the'),
#  ('de', 'of'),
#  ('à', 'to'),
#  ('et', 'and'),
#  ('un', 'a'),
#  ('dans', 'in'),
#  ('nous', 'we'),
#  ('boîte', 'can'),
#  ('dehors', 'out'),
#  ('autre', 'other'),
#  ('étaient', 'were'),
#  ('qui', 'which'),
#  ('faire', 'do'),
#  ('leur', 'their'),
#  ('temps', 'time'),
#  ('si', 'if'),
#  ('volonté', 'will'),
#  ('comment', 'how'),
#  ('dit', 'said'),
#  ('un', 'an'),
#  ('chaque', 'each'),
#  ('dire', 'tell'),
# ...

# %%
r.sample(words_translations, 10)

# %%
answers_by_word = {}

for word, translation in words_translations[ : 10] :
    print(word)
    t.sleep(3)
    print(translation)
    did_you_know = input('Did you know the translation? (y/n)').strip().lower()
    answers_by_word[word] = did_you_know
